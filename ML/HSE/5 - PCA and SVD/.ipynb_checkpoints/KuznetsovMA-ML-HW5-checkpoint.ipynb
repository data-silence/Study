# %% [markdown]
# # Домашнее задание №5
#
# Задание выполнил(а): `Максим Кузнецов`
#
# ### Общая информация
#
# __Дедлайн:__ 08.03.2022 23:30
#
#
# ### О задании
#
# Часть 1 содержит практическое задание на применение метода главных компонент.
#
# Часть 2 содержит практическое задание на применение метода One-Class SVM.
#
#
# ### Оценивание и штрафы
#
#
# #### 1. Метод главных компонент [5 баллов]
# * [Задание 1](#task1) [2 балла]
# * [Задание 2](#task2) [2 балл]
# * [Задание 3](#task3) [1 балл]
#
# #### 2. One-Class SVM [5 баллов]
# * [Задание 1](#task2_1) [1 балл]
# * [Задание 2](#task2_2) [1 балл]
# * [Задание 3](#task2_3) [3 балла]
#
# Итоговая оценка за домашнюю работу равна сумме набранных баллов.
#
# За сдачу задания позже срока на итоговую оценку за задание накладывается штраф в размере 0.25 балла в день (от оценки в 10 бальной шкале), но получить отрицательную оценку нельзя.
#
# __Внимание!__ Домашнее задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов.
#
# ### Формат сдачи
#
# Загрузка файлов с решениями происходит в системе [Anytask](https://anytask.org/course/890).

# %%
from scipy import io
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline

np.random.seed(0)

# %% [markdown]
# # Часть 1. Детектирование аномалий на основе метода главных компонент
# В файле Abilebe.mat представлены данные о трафике (количество байт в единицу времени) в сети Abilene для трех недель. Загрузим данные и посмотрим на ключи словаря.

# %%
data = io.loadmat('Abilene.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'odnames', 'X2', 'utc2', 'X3', 'utc3', 'X4', 'utc4'])

# %% [markdown]
# Словарь содержит:
# + матрицы X2, X3 и X4 с информацией о трафике между 121 парами “адресат-получатель” для каждой из трех недель
# + odnames с названиями всех пар “адресат-получатель”
# + вектора utc2; utc3, и utc4, содержащие моменты времени в формате UTC (в секундах), для которых были измерены значения трафика между рассмотренными парами “адресат-получатель”
#
# Нас интересует информация о трафике: хотелось бы реагировать на аномальные события в сети. Давайте попробуем оценить визуально.

# %%
X2 = data['X2']
X3 = data['X3']
X4 = data['X4']

# %%
X2.shape
# Out:
# (2016, 121)

# %%
plt.figure(figsize=(15,5))
plt.plot(X2, alpha=0.5);
plt.title('121 timeseries in week X2')
plt.grid(True)

# %%
idx = np.random.randint(0, 121, 10)
plt.figure(figsize=(15,5))
plt.plot(X2[:,idx], alpha=0.5);
plt.title('Random 10 timeseries in week X2')
plt.grid(True)

# %% [markdown]
# У нас слишком много рядов (высокая размерность данных 121) и их диапозоны значений довольно разные! Однако, видна какая-то структура. Это дает надежду на успешное снижение размерности задачи методом главных компонент. Предлагается использовать следующий алгоритм:
# 1. Оценить операторы сжатия и восстановления по компонентам второй недели (тренеровочная выборка)
# 2. Критерий аномальности наблюдения: слишком большая ошибка восстановления после сжатия

# %% [markdown]
# ### Задание 1 [2 балла] <a id="task1"></a>
# Вспомнить детали реализации алгоритма главных компонент (https://arxiv.org/pdf/1404.1100.pdf) и получить оператор сжатия.

# %% [markdown]
# Оценки будут производиться по главным компонентам **второй** недели

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# Сначала пропробую немного поюзать встроенную в sklearn реализацию, потом может посравниваю

# %%
pca = PCA(n_components = 1)
XPCAreduced = pca.fit_transform(np.transpose(X2))
len(XPCAreduced)
# Out:
# 121

# %%
pca.mean_
# Out:
# array([9766436.3119874 , 9774154.11080116, 9909356.30316899, ...,
#        8782934.31742521, 9005269.81883886, 6705166.18793139])

# %%
X2.shape
# Out:
# (2016, 121)

# %%
X2_mean = X2.mean(axis=1) 
# Возможно я сделал неправильно, но по условиям задачи, мы должны именно найти вектор по средним. 
# Если считать X2.mean по умолчанию (т.е. по нулевой оси), мы получим матрицу по средним.
U, s, V = np.linalg.svd((X2.T - X2_mean), compute_uv = True) 
X2_based_pc = U

# %%
U.shape, s.shape, V.shape
# Out:
# ((121, 121), (121,), (2016, 2016))

# %%
# ==> U.shape - матрица перехода

# %% [markdown]
# Подсчитаем метрику $\rho := $ какую долю дисперсии данных в каждую из трех недель (по отдельности) объясняют первые $d$ главных компонент, оценненые по первой неделе.
#
# Пусть
#  - $X$ матрица $121 \times 2016$ для которой нужно оценить такую метрику
#  - $\overline{X}$ вектор средних по строкам
#  - $U$ первые $d$ главных компонент, оценненые по первой неделе
#  - $Z(X) = U^T(X2 - \overline{X2})$ преобразование сжатия
#
# Тогда
#
# $$
# \rho(X) = \dfrac{\operatorname{trace}(Z - \overline{Z})(Z - \overline{Z})^T}{\operatorname{trace}(X - \overline{X})(X - \overline{X})^T}
# $$

# %% [markdown]
# Преобразование сжатия:

# %%
# mean_pc = X_mean_PC #  вектор средних по строкам
# based_pc = X_based_pc = U # первые d главных компонент от U?
# number_pc = d = # задаваемое число главных компонент 

def compression_operator(X, mean_pc, based_pc, number_pc):
    U_t = based_pc[: , :number_pc].T
    Z = U_t @ (X.T - mean_pc)
    return Z

def rho(X, mean_pc, based_pc, number_pc):
    Z = compression_operator(X, mean_pc, based_pc, number_pc)
    Z_mean = Z.T.mean(axis=1)
    if number_pc == 1:
        explained_var = np.trace(Z.T @ Z)
    else:
        explained_var = np.trace((Z-Z_mean) @ (Z-Z_mean).T)
    total_var = np.trace((X.T-mean_pc).T @ (X.T-mean_pc))
    return explained_var / total_var

# %% [markdown]
# ### Задание 2 [2 балла] <a id="task2"></a>
# Подсчитать, какую долю дисперсии данных в каждую из трех
# недель (по отдельности) объясняют первые d главных компонент (график зависимости $\rho$ от d), если главные компоненты были оценены по данным первой недели.

# %%
X2_var, = plt.plot(range(121), [rho(X2, X2_mean, X2_based_pc, d) for d in range(121)], label = 'second week')
X3_var, = plt.plot(range(121), [rho(X3, X2_mean, X2_based_pc, d) for d in range(121)], label = 'third week')
X4_var, = plt.plot(range(121), [rho(X4, X2_mean, X2_based_pc, d) for d in range(121)], label = 'fourth week')


plt.legend(handles=[X2_var, X3_var, X4_var], loc='best')
plt.axis('tight');
plt.grid();
# Out:
# <ipython-input-13-bed045e44442>:12: RuntimeWarning: Mean of empty slice.
#   Z_mean = Z.T.mean(axis=1)

# %% [markdown]
# Довольно приличная часть дисперсии объясняется через d главных компонент, если их взять больше двадцати; при шестидесяти компонент вообще ок.

# %% [markdown]
# Выпишем преобразование восстановления для $X$:
#
# $$\hat{X} = \overline{X2} + UZ(X)$$
#
# где $Z(X)$ - преобразование сжатия из прошлого задания.

# %%
def decompression_operator(compressed_X, mean_pc, based_pc, number_pc):
    U = based_pc[: , :number_pc]
    X_decompressed = mean_pc + U@compression_operator(compressed_X, mean_pc, based_pc, number_pc)
    return X_decompressed.T

# %%
def residual_matrix(X, mean_pc, based_pc, number_pc):
    compressed_X = compression_operator(X, mean_pc, based_pc, number_pc)
    decompressed_X = decompression_operator(X, mean_pc, based_pc, number_pc)
    res_matrix = X - decompressed_X
    return res_matrix

# %%
# test = residual_matrix(X3, X2_mean, X2_based_pc, 50)

# %%
# test.shape
# Out:
# (2016, 121)

# %% [markdown]
# ### Задание 3 [2 балла] <a id="task3"></a>
# Нарисовать график зависимости статистики $Q = (x - \hat x)^T(x - \hat x)$ ( https://www.ltu.se/cms_fs/1.51590!/pca_part%201_jackson_1980.pdf, интересующая формула: 31) от времени для каждой из трех недель по отдельности, при этом главные компоненты оценивать по данным первой недели, параметр d выбрать по результатам анализа зависимости доли диперсии от значения d для данных первой
# недели.

# %% [markdown]
# *Заметим*: Статистика $Q$ тогда в момент времени $t$ это квадрат нормы строки $t$ матрицы $X-\hat{X}$

# %%
def q_stat(residuals, moment):
    q_s = (np.linalg.norm(residuals[moment]))**2
    return q_s

# %% [markdown]
# Зафиксируем число компонет, с которым будем работать:

# %%
def broken_stick_pc_number_select(X):
    X_mean = X.mean(axis=1)
    U, s, V = np.linalg.svd((X2.T - X2_mean), compute_uv = True)
    s = s ** 2 / float(np.sum(s ** 2))
    broken_stick = np.array([np.sum(1.0 / np.arange(1, 122)[i:]) for i in range(121)]) / 121.0
    return s > broken_stick

# %%
broken_stick_pc_number_select(X2)
# Out:
# array([ True,  True,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# Я так понимаю, достаточно зафиксировать 3 компоненты?? Это противоречит тем выводам, которые я сделал выше, визуально оценивая график объясненной дисперсии. Ну да ладно

# %% [markdown]
# Выберем сколько будем использовать главных компонент матрицы $X2$. Посмотрим, сколько процентов дисперсии в $X2$ неделе они объясняют:

# %%
pc_const = broken_stick_pc_number_select(X2).sum()
np.sum(s[:pc_const] ** 2) / float(np.sum(s ** 2))
# Out:
# 0.925032749193261

# %% [markdown]
# Ну да, достаточно большую величину дисперсии объясняем. Ок, принято

# %% [markdown]
# Рассчитаем матрицу остатков для каждой из недели:

# %%
X2_resid = residual_matrix(X2, X2_mean, X2_based_pc, 50)
X3_resid = residual_matrix(X3, X2_mean, X2_based_pc, 50)
X4_resid = residual_matrix(X4, X2_mean, X2_based_pc, 50)

# %% [markdown]
# ### Задание 4 [2 балла] <a id="task4"></a>
# Теперь достаточно объявлять тревого для наблюдения с "большим" полученным остатком (ошибкой восстановления). Однако, здесь требуется уточнить, что такое "большим"?
# Один из возможных подходов к определению этого уровня статистически, предполагая нормальное распределение рассчитываемой статистики, нам остается задать уровень значимости $\alpha$. Расчет статистики реализован в функции q_critical. Математические детали можно прочитать здесь: ( https://www.ltu.se/cms_fs/1.51590!/pca_part%201_jackson_1980.pdf, интересующая формула: 33).
#
# Вам необходимо взять параметр $\alpha$ равным 0.05 и 0.01, привести на рисунках значение попрога $Q_\alpha$ (изобразив константной линией) и рассчитать число аномалий для каждой недели.

# %%
def q_critical(X, number_pc, alpha):
    X_mean = X.mean(axis=1)
    
    w, v = np.linalg.eig(np.cov((X.T - X_mean)))
    l = -np.sort(-w)[number_pc:]
    
    theta_one = l.sum()
    theta_two = (l**2).sum()
    theta_three = (l**3).sum()

    h = 1 - 2*(theta_one*theta_three)/3*(theta_two**2)
    
    if h > 0:
        c_alpha = stats.norm.ppf(1 - alpha) 
    else:
        c_alpha = stats.norm.ppf(alpha) 
        
    inside_brackets =  (c_alpha*h*((2*theta_two)**0.5)/theta_one) + (theta_two*h*(h-1)/(theta_one**2)) + 1
    
    return theta_one * np.power(inside_brackets, 1/h)

# %%
# X_mean = X2.mean(axis=1)

# w, v = np.linalg.eig(np.cov((X2.T - X2_mean)))
# l = -np.sort(-w)[5:]
# l.shape
# Out:
# (116,)

# %% [markdown]
# Добавим критические значения статистики и рассмотрим график для каждой недели отдельно:

# %%
def q_plot(X, X_resid, number_pc):
    f, axarr = plt.subplots(2, sharex=True, figsize=(40, 15))
    
    axarr[0].set_yscale('log')
    axarr[0].plot([q_stat(X_resid, t) for t in range(2016)])
    axarr[0].axhline(y=q_critical(X, number_pc, 0.01) , xmin=0, xmax=2016, linewidth=2, color = 'r')
    axarr[0].axhline(y=q_critical(X, number_pc, 0.05) , xmin=0, xmax=2016, linewidth=2, color = 'g')
    axarr[0].axis('tight')
    
    axarr[1].plot(X);
    axarr[1].axis('tight')

# %% [markdown]
# Выведем графики остатков c линиями $Q_{\alpha}$ (в логарифмической шкале)  и графики процессов (ocь времени совпадет):

# %% [markdown]
# ### Для недели $X2$

# %%
q_plot(X2, X2_resid, pc_const)

# %% [markdown]
# Число выбросов для $\alpha = 0.01$

# %%
sum([q_stat(X2_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.01))
# Out:
# 0

# %% [markdown]
# Число выбросов для $\alpha = 0.05$

# %%
sum([q_stat(X2_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.05))
# Out:
# 0

# %% [markdown]
# ### Для недели $X3$

# %%
q_plot(X3, X3_resid, pc_const)

# %% [markdown]
# Число выбросов для $\alpha = 0.01$

# %%
sum([q_stat(X3_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.01))
# Out:
# 0

# %% [markdown]
# Число выбросов для $\alpha = 0.05$

# %%
sum([q_stat(X3_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.05))
# Out:
# 0

# %% [markdown]
# ### Для недели $X4$

# %%
q_plot(X4, X4_resid, pc_const)

# %% [markdown]
# Число выбросов для  $\alpha=0.01$

# %%
sum([q_stat(X4_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.01))
# Out:
# 0

# %% [markdown]
# Число выбросов для $\alpha = 0.05$

# %%
sum([q_stat(X4_resid, t) for t in range(2016)] > q_critical(X2, pc_const, 0.05))
# Out:
# 0

# %%
Странно, но графики нормы остатков нигде не выходят за критическое значение

# %% [markdown]
# # Часть 2. Детектирование аномалий на основе One-Class SVM
# Рассмотрим задачу детектирование сетевых атак: Intrusion Detection. Будем использовать данные из KDD Cup 1999 Competition ( http://kdd.ics.uci.edu/databases/kddcup99/task.html). Полная база данных содержит около пяти миллионов записей о сетевых соединениях и различных типах атаках. Mы будем работать подвыборкой в 10% от оригинального датасета, отсутствие атаки обозначено как “normal”, а ее наличие — как “abnormal”.

# %%
from sklearn.svm import OneClassSVM
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(0)

from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

from sklearn.model_selection import train_test_split

from sklearn.utils.extmath import randomized_svd
from sklearn.decomposition import TruncatedSVD as TSVD

# %% [markdown]
# Считаем данные:

# %%
train = pd.read_csv('intrusion/train')
test = pd.read_csv('intrusion/test', delimiter = ';')
X_test = np.array(test.drop(test.columns[[0, 1, 2, 3]], axis=1))
np.save('test_np', X_test)

# %%
train.head(n=10)
# Out:
#    0  tcp  http  SF  181  5450  0.1  0.2  0.3  0.4  ...  9.1  1.00.1  0.00.6  \
# 0  0  tcp  http  SF  239   486    0    0    0    0  ...   19     1.0     0.0
# 1  0  tcp  http  SF  235  1337    0    0    0    0  ...   29     1.0     0.0
# 2  0  tcp  http  SF  219  1337    0    0    0    0  ...   39     1.0     0.0
# 3  0  tcp  http  SF  217  2032    0    0    0    0  ...   49     1.0     0.0
# 4  0  tcp  http  SF  217  2032    0    0    0    0  ...   59     1.0     0.0
# 5  0  tcp  http  SF  212  1940    0    0    0    0  ...   69     1.0     0.0
# 6  0  tcp  http  SF  159  4087    0    0    0    0  ...   79     1.0     0.0
# 7  0  tcp  http  SF  210   151    0    0    0    0  ...   89     1.0     0.0
# 8  0  tcp  http  SF  212   786    0    0    0    1  ...   99     1.0     0.0
# 9  0  tcp  http  SF  210   624    0    0    0    0  ...  109     1.0     0.0
#
#    0.11.1  0.00.7  0.00.8  0.00.9  0.00.10  0.00.11  normal.
# 0    0.05    0.00     0.0     0.0      0.0      0.0  normal.
# 1    0.03    0.00     0.0     0.0      0.0      0.0  normal.
# 2    0.03    0.00     0.0     0.0      0.0      0.0  normal.
# 3    0.02    0.00     0.0     0.0      0.0      0.0  normal.
# 4    0.02    0.00     0.0     0.0      0.0      0.0  normal.
# 5    1.00    0.04     0.0     0.0      0.0      0.0  normal.
# 6    0.09    0.04     0.0     0.0      0.0      0.0  normal.
# 7    0.12    0.04     0.0     0.0      0.0      0.0  normal.
# 8    0.12    0.05     0.0     0.0      0.0      0.0  normal.
# 9    0.06    0.05     0.0     0.0      0.0      0.0  normal.
#
# [10 rows x 42 columns]

# %% [markdown]
# В выборке метками $\{-1, 1\}$ обозначены аномальныe и нормальные наблюдения. Посмотрим на гистограмму классов:

# %%
y_train = (train['normal.'] == 'normal.') * 2 - 1
plt.hist(y_train, density=True);
plt.grid(True)

# %% [markdown]
# "Отрежем" не нужные для обучения колонки и целевую переменную.

# %%
X_train = train.drop(train.columns[[0, 1, 2, 3, 41]], axis=1)
y_train = y_train

# %% [markdown]
# Посмотрим на признаки. Самый простой способ оценить их качество, это посчитать дисперсию:

# %%
X_train.var()
# Out:
# 181        9.765770e+11
# 5450       1.091644e+09
# 0.1        4.453072e-05
# 0.2        1.817249e-02
# 0.3        3.036300e-05
# 0.4        6.116857e-01
# 0.5        2.408584e-04
# 1          1.262687e-01
# 0.6        3.233984e+00
# 0.7        1.113194e-04
# 0.8        6.072508e-05
# 0.9        4.051043e+00
# 0.10       9.296040e-03
# 0.11       1.214409e-04
# 0.12       1.330916e-03
# 0.13       0.000000e+00
# 0.14       0.000000e+00
# 0.15       1.384664e-03
# 8          4.543170e+04
# 8.1        6.067489e+04
# 0.00       1.449456e-01
# 0.00.1     1.451739e-01
# 0.00.2     5.364954e-02
# 0.00.3     5.389232e-02
# 1.00       1.506913e-01
# 0.00.4     6.757756e-03
# 0.00.5     2.027708e-02
# 9          4.191872e+03
# 9.1        1.124453e+04
# 1.00.1     1.687412e-01
# 0.00.6     1.193758e-02
# 0.11.1     2.316586e-01
# 0.00.7     1.775183e-03
# 0.00.8     1.448513e-01
# 0.00.9     1.450999e-01
# 0.00.10    5.317162e-02
# 0.00.11    5.296467e-02
# dtype: float64

# %%
X_train.shape
# Out:
# (494020, 37)

# %% [markdown]
# Видим, что есть два константных признака. Их можно удалить:

# %%
idx = np.where(X_train.var() == 0)[0]
cols = X_train.columns[idx]
X_train.drop(cols, axis=1, inplace=True)

# %% [markdown]
# Следующее, что можно сделать, это посмотреть попарные корреляции признаков:

# %%
plt.figure(figsize=(5,5));
plt.matshow(X_train.corr());

# %% [markdown]
# Такая структура обещает эффективное снижение размерности.

# %% [markdown]
# ### Задание 1 [1 балл] <a id="task2_1"></a>
# Оцените с помощью randomized SVD количество компонент достаточных для сжатия и дальнейшего ускорения обучения. (randomized SVD - быстрый способ оценки количества компонент)

# %%
X_train = np.array(X_train)
look_on_components =  randomized_svd(X_train, n_components=35)
U, Sigma, VT = look_on_components[2], look_on_components[1], look_on_components[0] 
plt.plot(Sigma);

# %%
U.shape, Sigma.shape, VT.shape
# Out:
# ((35, 35), (35,), (494020, 35))

# %% [markdown]
# Вроде, исходя из графика, три компоненты уже норм. Наверное можно было подобрать и счетно, через broken stick, но остановлюсь на визуальном выборе

# %% [markdown]
# ### Задание 2 [1 балл] <a id="task2_2"></a>
#
# Выберите количество компонент для сжатия и примените **truncated SVD**

# %%
model =  TSVD(n_components=3).fit(X_train) # не стал центрировать X_train, т.к. в документации написано, что не требутся
X_train_proj =  model.transform(X_train)
# X_train_proj.singular_values_
# X_train_proj.explained_variance_ratio_.sum()
# X_train_proj.components_
X_train_proj.shape
# Out:
# (494020, 3)

# %% [markdown]
# ### Задание 3 [3 балла] <a id="task2_3"></a>
#
# Проведите подбор параметров $\nu$ и $\gamma$ для модели OneClassSVM.
#
# Подбор сразу двух параметров может быть затруднен с вычислительной точки зрения (занимает много времени на слабых ПК). В таком случае возможны два выхода:
#
# 1) Проводить раздельный подбор гиперпараматров. Сначала поиск по $\nu$, затем при оптимальном $\nu_{opt}$ провести поиск по $\gamma$
#
# 2) Уменьшить размер датасета
#
# Поиск параметров предллагается провести в следующей области параметров:
#
# $\nu$: [0.5,1]
#
# $\gamma$: [0.1, 1]

# %%
# количество обьектов для сокращения выборки
# перед уменьшением выборки дайте шанс обучению на полном датасете
subsample_N = 10000 # вместо этого укажите свое N

X_subsample = X_train_proj[0:subsample_N]
y_subsample = y_train[0:subsample_N]

print(X_train_proj.shape)
print(X_subsample.shape)
# Out:
# (494020, 3)
# (10000, 3)

# %% [markdown]
# #### Проведем поиск по первому параметру $\nu$:

# %%
scores = {'accuracy_score': make_scorer(accuracy_score),}

model =  OneClassSVM()

grid = {
#     'gamma': np.linspace(0.1,1,10),
    'nu':np.linspace(0.5,1,100)
}

search = GridSearchCV(model, grid, scoring=scores,
                      n_jobs=-1, cv=2,
                      refit='accuracy_score')

search.fit(X_subsample, y_subsample)
# Out:
# GridSearchCV(cv=2, estimator=OneClassSVM(), n_jobs=-1,
#              param_grid={'nu': array([0.5       , 0.50505051, 0.51010101, 0.51515152, 0.52020202,
#        0.52525253, 0.53030303, 0.53535354, 0.54040404, 0.54545455,
#        0.55050505, 0.55555556, 0.56060606, 0.56565657, 0.57070707,
#        0.57575758, 0.58080808, 0.58585859, 0.59090909, 0.5959596 ,
#        0.6010101 , 0.60606061, 0.61111111, 0.61616162, 0.62121212,
#        0.626262...
#        0.85353535, 0.85858586, 0.86363636, 0.86868687, 0.87373737,
#        0.87878788, 0.88383838, 0.88888889, 0.89393939, 0.8989899 ,
#        0.9040404 , 0.90909091, 0.91414141, 0.91919192, 0.92424242,
#        0.92929293, 0.93434343, 0.93939394, 0.94444444, 0.94949495,
#        0.95454545, 0.95959596, 0.96464646, 0.96969697, 0.97474747,
#        0.97979798, 0.98484848, 0.98989899, 0.99494949, 1.        ])},
#              refit='accuracy_score',
#              scoring={'accuracy_score': make_scorer(accuracy_score)})

# %% [markdown]
# #### Построим результаты валидации:

# %%
 # your code here
print("nu:     ", search.cv_results_['param_nu'].data)
print("scores: ", search.cv_results_['mean_test_accuracy_score'])
# Out:
# nu:      [0.5 0.5050505050505051 0.51010101010101 0.5151515151515151
#  0.5202020202020202 0.5252525252525253 0.5303030303030303
#  0.5353535353535354 0.5404040404040404 0.5454545454545454
#  0.5505050505050505 0.5555555555555556 0.5606060606060606
#  0.5656565656565656 0.5707070707070707 0.5757575757575758
#  0.5808080808080808 0.5858585858585859 0.5909090909090909
#  0.595959595959596 0.601010101010101 0.6060606060606061 0.6111111111111112
#  0.6161616161616161 0.6212121212121212 0.6262626262626263
#  0.6313131313131313 0.6363636363636364 0.6414141414141414
#  0.6464646464646464 0.6515151515151515 0.6565656565656566
#  0.6616161616161617 0.6666666666666667 0.6717171717171717
#  0.6767676767676768 0.6818181818181819 0.6868686868686869
#  0.6919191919191919 0.696969696969697 0.702020202020202 0.7070707070707071
#  0.7121212121212122 0.7171717171717171 0.7222222222222222
#  0.7272727272727273 0.7323232323232324 0.7373737373737375
#  0.7424242424242424 0.7474747474747475 0.7525252525252526
#  0.7575757575757576 0.7626262626262627 0.7676767676767677
#  0.7727272727272727 0.7777777777777778 0.7828282828282829
#  0.7878787878787878 0.7929292929292929 0.797979797979798 0.803030303030303
#  0.8080808080808082 0.8131313131313131 0.8181818181818182
#  0.8232323232323233 0.8282828282828283 0.8333333333333334
#  0.8383838383838385 0.8434343434343434 0.8484848484848485
#  0.8535353535353536 0.8585858585858586 0.8636363636363636
#  0.8686868686868687 0.8737373737373737 0.8787878787878789
#  0.8838383838383839 0.8888888888888888 0.893939393939394 0.898989898989899
#  0.9040404040404041 0.9090909090909092 0.9141414141414141
#  0.9191919191919192 0.9242424242424243 0.9292929292929293
#  0.9343434343434344 0.9393939393939394 0.9444444444444444
#  0.9494949494949496 0.9545454545454546 0.9595959595959596
#  0.9646464646464648 0.9696969696969697 0.9747474747474748
#  0.9797979797979799 0.9848484848484849 0.98989898989899 0.994949494949495
#  1.0]
# scores:  [0.6362 0.6333 0.6307 0.6268 0.6246 0.6222 0.6191 0.6167 0.6142 0.6119
#  0.6095 0.6052 0.6035 0.6015 0.5983 0.5951 0.592  0.5892 0.5871 0.5836
#  0.5805 0.5765 0.5728 0.5696 0.5667 0.5654 0.5618 0.5581 0.5552 0.5528
#  0.55   0.5463 0.5443 0.5413 0.539  0.535  0.534  0.5312 0.5278 0.5251
#  0.5224 0.5204 0.5181 0.5149 0.511  0.5073 0.5036 0.4999 0.4967 0.4931
#  0.49   0.4846 0.4808 0.478  0.4733 0.4674 0.4623 0.4561 0.4504 0.4449
#  0.4401 0.4343 0.4283 0.4213 0.4156 0.4123 0.4072 0.4014 0.3969 0.3908
#  0.3846 0.3808 0.374  0.3675 0.3611 0.3559 0.3495 0.3436 0.3393 0.3336
#  0.3273 0.3212 0.316  0.3107 0.3076 0.3009 0.2952 0.29   0.2837 0.2784
#  0.2733 0.2679 0.2625 0.2554 0.2485 0.2441 0.2393 0.2329 0.2273 0.2214]

# %% [markdown]
# Выберите $\nu$, обеспечивающее наибольший score на кроссвалидации, за исключением $\nu=1$, т.к. это противоречит физическому смыслу задачи

# %%
score =  search.cv_results_['mean_test_accuracy_score']
# score
nu_max = score[score < 0.8].max()
nu_max_number = score[score < 0.8].argmax()
print(nu_max, nu_max_number)
# Out:
# 0.6362 0

# %%
nu_opt = search.cv_results_['param_nu'][nu_max_number]
nu_opt
# Out:
# 0.5

# %% [markdown]
# Теперь необходимо подобрать $\gamma$. Оптимальнее конечно было бы подбирать сразу оба параметра, но если это не возможно для ваших ресурсов в силу вычислительной сложности, то проведите отдельный поиск $\gamma$ при найденном ранее $\nu_{opt}$.

# %% [markdown]
# # Задание
# + Используя кроссвалидацию оценить качество определения аномальных наблюдений с помощью обученной модели One-Class SVM
# + Исследовать зависимость этого качества от параметров метода (ширина ядра, доля выбросов в модели, задаваемая параметром $\nu$)

# %%
model = OneClassSVM(nu=nu_opt, kernel='rbf')

grid = {
    'gamma': np.linspace(1e-10,1,10) # очень плохие результаты при рек.диапазоне (0.22). При нижней границе1e-10 неплохо
}

search = GridSearchCV(model, grid, scoring=scores,
                      n_jobs=-1, cv=2,
                      refit='accuracy_score')

search.fit(X_subsample, y_subsample)
# Out:
# GridSearchCV(cv=2, estimator=OneClassSVM(), n_jobs=-1,
#              param_grid={'gamma': array([1.00000000e-10, 1.11111111e-01, 2.22222222e-01, 3.33333333e-01,
#        4.44444444e-01, 5.55555556e-01, 6.66666667e-01, 7.77777778e-01,
#        8.88888889e-01, 1.00000000e+00])},
#              refit='accuracy_score',
#              scoring={'accuracy_score': make_scorer(accuracy_score)})

# %%
# your code here
print("gamma:     ", search.cv_results_['param_gamma'].data)
print("scores: ", search.cv_results_['mean_test_accuracy_score'])
# Out:
# gamma:      [1e-10 0.11111111119999999 0.2222222223 0.3333333334 0.4444444445
#  0.5555555556 0.6666666667 0.7777777777999999 0.8888888889 1.0]
# scores:  [0.737  0.2248 0.2241 0.2239 0.2241 0.2238 0.224  0.2241 0.2242 0.223 ]

# %%
score1 =  search.cv_results_['mean_test_accuracy_score']
gamma_max = score[score < 0.8].max()
gamma_max_number = score[score < 0.8].argmax()
gamma_opt = search.cv_results_['param_gamma'][gamma_max_number]
gamma_opt
# Out:
# 1e-10

# %%
Получается, что чем уже (меньше) ширина ядра ню, и чем меньше доля выбросов гамма, тем лучше качество модели.

# %% [markdown]
# Не вижу, чтобы это было написано в задании, но сделаем это - обучим One-Class SVM на найденных оптимальных параметрах и посчитаем метрики качества

# %%
from sklearn import metrics  
model = OneClassSVM(nu=nu_opt, kernel='rbf', gamma=gamma_opt) 
model.fit(X_subsample)
predicts = model.predict(X_subsample)  
targets = y_subsample


print("Accuracy: ", metrics.accuracy_score(targets, predicts))  
print("Precision: ", metrics.precision_score(targets, predicts))  
print("Recall: ", metrics.recall_score(targets, predicts))  
print("Аuc: ", metrics.roc_auc_score(targets, predicts))
# Out:
# Accuracy:  0.7206
# Precision:  0.9992
# Recall:  0.6416645260724377
# Аuc:  0.8199289206694618

# %% [markdown]
# Не блестяще. Нет времени, да и лень, но нужно было, конечно, перебрать все ядра: {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} и находить все оптимальные параметры по ним.
